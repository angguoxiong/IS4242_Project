# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Dataset

# %%
df1 = pd.read_csv('movies_metadata.csv')
df2 = pd.read_csv('ratings.csv')
# Out:
# C:\Users\alici\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df2.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %% [markdown]
# #### Merge User Rating with Movies

# %%
df1 = df1[~df1['id'].isin(['2014-01-01', '2012-09-29', '1997-08-20'])]
df1['id'] = df1['id'].astype(int)
df_merged = df2.merge(df1, left_on = 'movieId', right_on = 'id', how = 'left')

# %%
df_merged.head(5)
# Out:
#    userId  movieId  rating   timestamp  adult  \
# 0       1      110     1.0  1425941529  False
# 1       1      147     4.5  1425942435  False
# 2       1      858     5.0  1425941523  False
# 3       1     1221     5.0  1425941546    NaN
# 4       1     1246     5.0  1425941556  False
#
#                                belongs_to_collection    budget  \
# 0  {'id': 131, 'name': 'Three Colors Collection',...         0
# 1  {'id': 185682, 'name': 'The Adventures of Anto...         0
# 2                                                NaN  21000000
# 3                                                NaN       NaN
# 4  {'id': 1575, 'name': 'Rocky Collection', 'post...  24000000
#
#                                               genres               homepage  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...                    NaN
# 1                      [{'id': 18, 'name': 'Drama'}]                    NaN
# ...

# %%
# create boolean mask of NaN values
nan_mask = df_merged.isna()

# count number of True values in each column
nan_count = nan_mask.sum(axis=0)

# print number of NaN values in each column
print(nan_count/len(df_merged))
# Out:
# userId                   0.000000
# movieId                  0.000000
# rating                   0.000000
# timestamp                0.000000
# adult                    0.560520
# belongs_to_collection    0.895272
# budget                   0.560520
# genres                   0.560520
# homepage                 0.894655
# id                       0.560520
# imdb_id                  0.560521
# original_language        0.560520
# original_title           0.560520
# overview                 0.562082
# popularity               0.560520
# poster_path              0.560895
# production_companies     0.560520
# production_countries     0.560520
# release_date             0.560790
# revenue                  0.560520
# runtime                  0.560559
# spoken_languages         0.560520
# status                   0.560553
# tagline                  0.694878
# title                    0.560520
# video                    0.560520
# vote_average             0.560520
# ...

# %%
df_merged.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp', 'adult',
#        'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df_final = df_merged.drop(columns = ['timestamp', 'budget', 'homepage', 'id',
                                     'imdb_id', 'overview', 'poster_path', 'tagline', 'movieId','original_title', 'title',
                                    'belongs_to_collection', 'video','title'])

# %%
df_final.head(5)
# Out:
#    userId  rating  adult                                             genres  \
# 0       1     1.0  False  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 1       1     4.5  False                      [{'id': 18, 'name': 'Drama'}]
# 2       1     5.0  False  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3       1     5.0    NaN                                                NaN
# 4       1     5.0  False                      [{'id': 18, 'name': 'Drama'}]
#
#   original_language popularity  \
# 0                fr   7.832755
# 1                fr   7.268688
# 2                en  10.234919
# 3               NaN        NaN
# 4                en  11.697604
#
#                                 production_companies  \
# 0  [{'name': 'Zespół Filmowy TOR', 'id': 38}, {'n...
# 1  [{'name': 'Les Films du Carrosse', 'id': 53}, ...
# 2          [{'name': 'TriStar Pictures', 'id': 559}]
# 3                                                NaN
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### Extract genres from dictionary

# %%
df_final['genres_list'] = df_final['genres'].apply(lambda row: [d['name'] for d in json.loads(row.replace("'", "\""))] if isinstance(row, str) else [])

# %% [markdown]
# #### Extract num_years since movie released

# %%
from datetime import datetime

df_final['years_since_released'] = df_final['release_date'].apply(lambda x: x if pd.isna(x) else 2023-datetime.strptime(str(x), "%Y-%m-%d").year)

# %%
df_final.drop(columns = ['genres', 'release_date'], inplace = True)
df_final.head(5)

# %% [markdown]
# #### Replace True False with Binary Value

# %%
df_final['adult'] = df_final['adult'].replace({"True": 1, "False": 0})
df_final['video'] = df_final['video'].replace({"True": 1, "False": 0})

# %%
df_final

# %%
len(df_final['original_language'].unique())
